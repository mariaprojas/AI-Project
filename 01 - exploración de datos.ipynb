# %% [markdown]
# # Exploración de datos [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mariaprojas/AI-Project/blob/master/01%20-%20exploración%20de%20datos.ipynb)

# %% [markdown]
# ### Importando las librerias necesarias

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Importando el archivo del dataset desde Google Drive

# %%
# !pip install gdown

import gdown

# Define ID 
archivo_id = "1tQl5NDSp6TPxqDiUe342dYhC1j8yRg-v"

# Asigna nombre para el archivo en Colab
d1 = "dataset_1.csv"

# Construye el enlace de descarga del archivo
enlace_descarga = "https://drive.google.com/uc?id=" + archivo_id

# Descarga el archivo desde el enlace de descarga y lo guarda en Colab
gdown.download(enlace_descarga, d1, quiet=False)

# Lee el archivo y lo almacena en un data frame
d = pd.read_csv("dataset_1.csv")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (4.6.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.12.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.27.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.65.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.4.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# Downloading...
# From: https://drive.google.com/uc?id=1tQl5NDSp6TPxqDiUe342dYhC1j8yRg-v
# To: /content/dataset_1.csv
# 100%|██████████| 286M/286M [00:05<00:00, 50.0MB/s]
# <ipython-input-3-9799088c9063>:18: DtypeWarning: Columns (28,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   d = pd.read_csv("dataset_1.csv")

# %% [markdown]
# ### Descripción Dataset

# %% [markdown]
# Tamaño del Dataframe

# %%
print (d.shape)
# Out:
# (500000, 83)

# %% [markdown]
# Tipos de datos en el dataframe

# %%
for c in d.columns:
    print ("%20s"%c, d[c].dtype)
# Out:
#    MachineIdentifier object
#          ProductName object
#        EngineVersion object
#           AppVersion object
#         AvSigVersion object
#               IsBeta int64
#     RtpStateBitfield float64
#     IsSxsPassiveMode int64
# DefaultBrowsersIdentifier float64
# AVProductStatesIdentifier float64
#  AVProductsInstalled float64
#    AVProductsEnabled float64
#               HasTpm int64
#    CountryIdentifier int64
#       CityIdentifier float64
# OrganizationIdentifier float64
#    GeoNameIdentifier float64
# LocaleEnglishNameIdentifier int64
#             Platform object
#            Processor object
#                OsVer object
#              OsBuild int64
#              OsSuite int64
# OsPlatformSubRelease object
#           OsBuildLab object
#           SkuEdition object
#          IsProtected float64
#      AutoSampleOptIn int64
#              PuaMode object
#                SMode float64
#      IeVerIdentifier float64
#          SmartScreen object
#             Firewall float64
#         UacLuaenable float64
# Census_MDC2FormFactor object
#  Census_DeviceFamily object
# Census_OEMNameIdentifier float64
# Census_OEMModelIdentifier float64
# Census_ProcessorCoreCount float64
# Census_ProcessorManufacturerIdentifier float64
# Census_ProcessorModelIdentifier float64
# Census_ProcessorClass object
# Census_PrimaryDiskTotalCapacity float64
# Census_PrimaryDiskTypeName object
# Census_SystemVolumeTotalCapacity float64
# Census_HasOpticalDiskDrive float64
# Census_TotalPhysicalRAM float64
# Census_ChassisTypeName object
# Census_InternalPrimaryDiagonalDisplaySizeInInches float64
# Census_InternalPrimaryDisplayResolutionHorizontal float64
# Census_InternalPrimaryDisplayResolutionVertical float64
# Census_PowerPlatformRoleName object
# Census_InternalBatteryType object
# Census_InternalBatteryNumberOfCharges float64
#     Census_OSVersion object
# Census_OSArchitecture object
#      Census_OSBranch object
# Census_OSBuildNumber float64
# Census_OSBuildRevision float64
#     Census_OSEdition object
#     Census_OSSkuName object
# Census_OSInstallTypeName object
# Census_OSInstallLanguageIdentifier float64
# Census_OSUILocaleIdentifier float64
# Census_OSWUAutoUpdateOptionsName object
# Census_IsPortableOperatingSystem float64
# Census_GenuineStateName object
# Census_ActivationChannel object
# Census_IsFlightingInternal float64
# Census_IsFlightsDisabled float64
#    Census_FlightRing object
# Census_ThresholdOptIn float64
# Census_FirmwareManufacturerIdentifier float64
# Census_FirmwareVersionIdentifier float64
# Census_IsSecureBootEnabled float64
# Census_IsWIMBootEnabled float64
# Census_IsVirtualDevice float64
# Census_IsTouchEnabled float64
#  Census_IsPenCapable float64
# Census_IsAlwaysOnAlwaysConnectedCapable float64
#         Wdft_IsGamer float64
# Wdft_RegionIdentifier float64
#        HasDetections float64

# %% [markdown]
# Columnas númericas

# %%
d._get_numeric_data().describe().T
#d.info()
# Out:
#                                                       count          mean  \
# IsBeta                                             500000.0  6.000000e-06
# RtpStateBitfield                                   498319.0  6.844822e+00
# IsSxsPassiveMode                                   500000.0  1.727600e-02
# DefaultBrowsersIdentifier                           24069.0  1.661169e+03
# AVProductStatesIdentifier                          497973.0  4.783555e+04
# AVProductsInstalled                                497973.0  1.327104e+00
# AVProductsEnabled                                  497973.0  1.021025e+00
# HasTpm                                             500000.0  9.877660e-01
# CountryIdentifier                                  500000.0  1.080238e+02
# CityIdentifier                                     481915.0  8.128360e+04
# OrganizationIdentifier                             346025.0  2.485573e+01
# GeoNameIdentifier                                  499983.0  1.695433e+02
# LocaleEnglishNameIdentifier                        500000.0  1.227070e+02
# OsBuild                                            500000.0  1.571650e+04
# OsSuite                                            500000.0  5.750408e+02
# IsProtected                                        497982.0  9.454197e-01
# AutoSampleOptIn                                    500000.0  2.600000e-05
# SMode                                              470028.0  4.616746e-04
# IeVerIdentifier                                    496587.0  1.265588e+02
# Firewall                                           494766.0  9.784282e-01
# UacLuaenable                                       499388.0  2.645487e+01
# Census_OEMNameIdentifier                           494587.0  2.220442e+03
# Census_OEMModelIdentifier                          494180.0  2.392326e+05
# Census_ProcessorCoreCount                          497721.0  3.985293e+00
# Census_ProcessorManufacturerIdentifier             497720.0  4.531449e+00
# Census_ProcessorModelIdentifier                    497719.0  2.370675e+03
# Census_PrimaryDiskTotalCapacity                    497017.0  1.693201e+07
# Census_SystemVolumeTotalCapacity                   497017.0  3.773794e+05
# Census_HasOpticalDiskDrive                         499990.0  7.724554e-02
# Census_TotalPhysicalRAM                            495461.0  6.107104e+03
# Census_InternalPrimaryDiagonalDisplaySizeInInches  497361.0  1.665213e+01
# Census_InternalPrimaryDisplayResolutionHorizontal  497368.0  1.546882e+03
# Census_InternalPrimaryDisplayResolutionVertical    497368.0  8.971412e+02
# Census_InternalBatteryNumberOfCharges              484963.0  1.122764e+09
# Census_OSBuildNumber                               499990.0  1.583150e+04
# Census_OSBuildRevision                             499990.0  9.764701e+02
# Census_OSInstallLanguageIdentifier                 496523.0  1.459466e+01
# Census_OSUILocaleIdentifier                        499990.0  6.040084e+01
# Census_IsPortableOperatingSystem                   499990.0  5.720114e-04
# Census_IsFlightingInternal                          84828.0  1.178856e-05
# Census_IsFlightsDisabled                           491003.0  6.109942e-06
# Census_ThresholdOptIn                              183065.0  3.113648e-04
# Census_FirmwareManufacturerIdentifier              489628.0  4.026611e+02
# Census_FirmwareVersionIdentifier                   490924.0  3.301778e+04
# Census_IsSecureBootEnabled                         499990.0  4.851777e-01
# Census_IsWIMBootEnabled                            183464.0  0.000000e+00
# Census_IsVirtualDevice                             499128.0  6.976166e-03
# Census_IsTouchEnabled                              499990.0  1.251725e-01
# Census_IsPenCapable                                499990.0  3.800076e-02
# Census_IsAlwaysOnAlwaysConnectedCapable            496041.0  5.780772e-02
# Wdft_IsGamer                                       483081.0  2.835963e-01
# Wdft_RegionIdentifier                              483081.0  7.879395e+00
# HasDetections                                      499990.0  4.994080e-01
#
#                                                             std      min  \
# IsBeta                                             2.449485e-03      0.0
# RtpStateBitfield                                   1.027932e+00      0.0
# IsSxsPassiveMode                                   1.302980e-01      0.0
# DefaultBrowsersIdentifier                          1.007127e+03      7.0
# AVProductStatesIdentifier                          1.403910e+04     16.0
# AVProductsInstalled                                5.235211e-01      1.0
# AVProductsEnabled                                  1.677075e-01      0.0
# HasTpm                                             1.099289e-01      0.0
# CountryIdentifier                                  6.302368e+01      1.0
# CityIdentifier                                     4.892775e+04      7.0
# OrganizationIdentifier                             5.595823e+00      1.0
# GeoNameIdentifier                                  8.935308e+01      1.0
# LocaleEnglishNameIdentifier                        6.924087e+01      1.0
# OsBuild                                            2.194597e+03   7600.0
# OsSuite                                            2.481218e+02     16.0
# IsProtected                                        2.271594e-01      0.0
# AutoSampleOptIn                                    5.098958e-03      0.0
# SMode                                              2.148168e-02      0.0
# IeVerIdentifier                                    4.274291e+01      1.0
# Firewall                                           1.452808e-01      0.0
# UacLuaenable                                       1.272190e+04      0.0
# Census_OEMNameIdentifier                           1.316099e+03     74.0
# Census_OEMModelIdentifier                          7.201450e+04     22.0
# Census_ProcessorCoreCount                          2.089710e+00      1.0
# Census_ProcessorManufacturerIdentifier             1.286965e+00      1.0
# Census_ProcessorModelIdentifier                    8.405169e+02      6.0
# Census_PrimaryDiskTotalCapacity                    1.157518e+10  10240.0
# Census_SystemVolumeTotalCapacity                   3.248764e+05   9200.0
# Census_HasOpticalDiskDrive                         2.669809e-01      0.0
# Census_TotalPhysicalRAM                            5.022547e+03    512.0
# Census_InternalPrimaryDiagonalDisplaySizeInInches  5.799212e+00      4.9
# Census_InternalPrimaryDisplayResolutionHorizontal  3.675010e+02     -1.0
# Census_InternalPrimaryDisplayResolutionVertical    2.142297e+02     -1.0
# Census_InternalBatteryNumberOfCharges              1.887231e+09      0.0
# Census_OSBuildNumber                               1.965539e+03   9200.0
# Census_OSBuildRevision                             2.940349e+03      0.0
# Census_OSInstallLanguageIdentifier                 1.018390e+01      1.0
# Census_OSUILocaleIdentifier                        4.494372e+01      2.0
# Census_IsPortableOperatingSystem                   2.390994e-02      0.0
# Census_IsFlightingInternal                         3.433447e-03      0.0
# Census_IsFlightsDisabled                           2.471825e-03      0.0
# Census_ThresholdOptIn                              1.764283e-02      0.0
# Census_FirmwareManufacturerIdentifier              2.215881e+02     11.0
# Census_FirmwareVersionIdentifier                   2.121324e+04     27.0
# Census_IsSecureBootEnabled                         4.997808e-01      0.0
# Census_IsWIMBootEnabled                            0.000000e+00      0.0
# Census_IsVirtualDevice                             8.323169e-02      0.0
# Census_IsTouchEnabled                              3.309147e-01      0.0
# Census_IsPenCapable                                1.911983e-01      0.0
# Census_IsAlwaysOnAlwaysConnectedCapable            2.333797e-01      0.0
# Wdft_IsGamer                                       4.507437e-01      0.0
# Wdft_RegionIdentifier                              4.549298e+00      1.0
# HasDetections                                      5.000001e-01      0.0
#
#                                                         25%       50%  \
# IsBeta                                                  0.0       0.0
# RtpStateBitfield                                        7.0       7.0
# IsSxsPassiveMode                                        0.0       0.0
# DefaultBrowsersIdentifier                             788.0    1632.0
# AVProductStatesIdentifier                           49480.0   53447.0
# AVProductsInstalled                                     1.0       1.0
# AVProductsEnabled                                       1.0       1.0
# HasTpm                                                  1.0       1.0
# CountryIdentifier                                      51.0      97.0
# CityIdentifier                                      36825.0   82373.0
# OrganizationIdentifier                                 18.0      27.0
# GeoNameIdentifier                                      89.0     181.0
# LocaleEnglishNameIdentifier                            74.0      88.0
# OsBuild                                             15063.0   16299.0
# OsSuite                                               256.0     768.0
# IsProtected                                             1.0       1.0
# AutoSampleOptIn                                         0.0       0.0
# SMode                                                   0.0       0.0
# IeVerIdentifier                                       111.0     117.0
# Firewall                                                1.0       1.0
# UacLuaenable                                            1.0       1.0
# Census_OEMNameIdentifier                             1443.0    2102.0
# Census_OEMModelIdentifier                          189718.0  247520.0
# Census_ProcessorCoreCount                               2.0       4.0
# Census_ProcessorManufacturerIdentifier                  5.0       5.0
# Census_ProcessorModelIdentifier                      1998.0    2500.0
# Census_PrimaryDiskTotalCapacity                    239372.0  476940.0
# Census_SystemVolumeTotalCapacity                   120754.0  249451.0
# Census_HasOpticalDiskDrive                              0.0       0.0
# Census_TotalPhysicalRAM                              4096.0    4096.0
# Census_InternalPrimaryDiagonalDisplaySizeInInches      13.9      15.5
# Census_InternalPrimaryDisplayResolutionHorizontal    1366.0    1366.0
# Census_InternalPrimaryDisplayResolutionVertical       768.0     768.0
# Census_InternalBatteryNumberOfCharges                   0.0       0.0
# Census_OSBuildNumber                                15063.0   16299.0
# Census_OSBuildRevision                                165.0     285.0
# Census_OSInstallLanguageIdentifier                      8.0       9.0
# Census_OSUILocaleIdentifier                            31.0      34.0
# Census_IsPortableOperatingSystem                        0.0       0.0
# Census_IsFlightingInternal                              0.0       0.0
# Census_IsFlightsDisabled                                0.0       0.0
# Census_ThresholdOptIn                                   0.0       0.0
# Census_FirmwareManufacturerIdentifier                 142.0     500.0
# Census_FirmwareVersionIdentifier                    13156.0   33066.0
# Census_IsSecureBootEnabled                              0.0       0.0
# Census_IsWIMBootEnabled                                 0.0       0.0
# Census_IsVirtualDevice                                  0.0       0.0
# Census_IsTouchEnabled                                   0.0       0.0
# Census_IsPenCapable                                     0.0       0.0
# Census_IsAlwaysOnAlwaysConnectedCapable                 0.0       0.0
# Wdft_IsGamer                                            0.0       0.0
# Wdft_RegionIdentifier                                   3.0      10.0
# HasDetections                                           0.0       0.0
#
#                                                             75%           max
# IsBeta                                             0.000000e+00  1.000000e+00
# RtpStateBitfield                                   7.000000e+00  3.500000e+01
# IsSxsPassiveMode                                   0.000000e+00  1.000000e+00
# DefaultBrowsersIdentifier                          2.388000e+03  3.197000e+03
# AVProductStatesIdentifier                          5.344700e+04  7.049300e+04
# AVProductsInstalled                                2.000000e+00  6.000000e+00
# AVProductsEnabled                                  1.000000e+00  4.000000e+00
# HasTpm                                             1.000000e+00  1.000000e+00
# CountryIdentifier                                  1.600000e+02  2.220000e+02
# CityIdentifier                                     1.236550e+05  1.679620e+05
# OrganizationIdentifier                             2.700000e+01  5.200000e+01
# GeoNameIdentifier                                  2.670000e+02  2.960000e+02
# LocaleEnglishNameIdentifier                        1.820000e+02  2.830000e+02
# OsBuild                                            1.713400e+04  1.824400e+04
# OsSuite                                            7.680000e+02  7.840000e+02
# IsProtected                                        1.000000e+00  1.000000e+00
# AutoSampleOptIn                                    0.000000e+00  1.000000e+00
# SMode                                              0.000000e+00  1.000000e+00
# IeVerIdentifier                                    1.370000e+02  4.290000e+02
# Firewall                                           1.000000e+00  1.000000e+00
# UacLuaenable                                       1.000000e+00  6.357062e+06
# Census_OEMNameIdentifier                           2.668000e+03  6.143000e+03
# Census_OEMModelIdentifier                          3.056790e+05  3.454900e+05
# Census_ProcessorCoreCount                          4.000000e+00  1.040000e+02
# Census_ProcessorManufacturerIdentifier             5.000000e+00  1.000000e+01
# Census_ProcessorModelIdentifier                    2.874000e+03  4.472000e+03
# Census_PrimaryDiskTotalCapacity                    9.538690e+05  8.160437e+12
# Census_SystemVolumeTotalCapacity                   4.759750e+05  1.144346e+07
# Census_HasOpticalDiskDrive                         0.000000e+00  1.000000e+00
# Census_TotalPhysicalRAM                            8.192000e+03  5.242880e+05
# Census_InternalPrimaryDiagonalDisplaySizeInInches  1.720000e+01  1.420000e+02
# Census_InternalPrimaryDisplayResolutionHorizontal  1.920000e+03  7.680000e+03
# Census_InternalPrimaryDisplayResolutionVertical    1.080000e+03  4.320000e+03
# Census_InternalBatteryNumberOfCharges              4.294967e+09  4.294967e+09
# Census_OSBuildNumber                               1.713400e+04  1.824400e+04
# Census_OSBuildRevision                             5.470000e+02  2.170300e+04
# Census_OSInstallLanguageIdentifier                 2.000000e+01  3.900000e+01
# Census_OSUILocaleIdentifier                        9.000000e+01  1.610000e+02
# Census_IsPortableOperatingSystem                   0.000000e+00  1.000000e+00
# Census_IsFlightingInternal                         0.000000e+00  1.000000e+00
# Census_IsFlightsDisabled                           0.000000e+00  1.000000e+00
# Census_ThresholdOptIn                              0.000000e+00  1.000000e+00
# Census_FirmwareManufacturerIdentifier              5.560000e+02  1.083000e+03
# Census_FirmwareVersionIdentifier                   5.243600e+04  7.209600e+04
# Census_IsSecureBootEnabled                         1.000000e+00  1.000000e+00
# Census_IsWIMBootEnabled                            0.000000e+00  0.000000e+00
# Census_IsVirtualDevice                             0.000000e+00  1.000000e+00
# Census_IsTouchEnabled                              0.000000e+00  1.000000e+00
# Census_IsPenCapable                                0.000000e+00  1.000000e+00
# Census_IsAlwaysOnAlwaysConnectedCapable            0.000000e+00  1.000000e+00
# Wdft_IsGamer                                       1.000000e+00  1.000000e+00
# Wdft_RegionIdentifier                              1.100000e+01  1.500000e+01
# HasDetections                                      1.000000e+00  1.000000e+00

# %% [markdown]
# Variables categoricas

# %%
ccols = [i for i in d.columns if not i in d._get_numeric_data()]
print (ccols)
print (len(ccols))
# Out:
# ['MachineIdentifier', 'ProductName', 'EngineVersion', 'AppVersion', 'AvSigVersion', 'Platform', 'Processor', 'OsVer', 'OsPlatformSubRelease', 'OsBuildLab', 'SkuEdition', 'PuaMode', 'SmartScreen', 'Census_MDC2FormFactor', 'Census_DeviceFamily', 'Census_ProcessorClass', 'Census_PrimaryDiskTypeName', 'Census_ChassisTypeName', 'Census_PowerPlatformRoleName', 'Census_InternalBatteryType', 'Census_OSVersion', 'Census_OSArchitecture', 'Census_OSBranch', 'Census_OSEdition', 'Census_OSSkuName', 'Census_OSInstallTypeName', 'Census_OSWUAutoUpdateOptionsName', 'Census_GenuineStateName', 'Census_ActivationChannel', 'Census_FlightRing']
# 30

# %%
import dask.dataframe as dd

# Convertir el dataframe de Pandas en un objeto de Dask
df_dask = dd.from_pandas(d, npartitions=4)

# Lista de nombres de columnas categóricas
#ccols
# Contar los valores únicos en cada columna categórica en paralelo
for c in ccols:
    unique_values = df_dask[c].value_counts().compute()
    print(f"Columna {c} tiene {unique_values.shape[0]} valores únicos")
    print(unique_values)
# Out:
# Columna MachineIdentifier tiene 500000 valores únicos
# 113e0cc2e00e739e28af62ee1495d84e    1
# fb37ef81e63725e203627f7bdeade69d    1
# fb37ec32df3957290e28917944978e11    1
# fb37ea27bc20aa0c8c49097a4a5cb7ed    1
# fb37e7df25632c9975e54931ff09e345    1
#                                    ..
# f66db86277214f998a69116ee2dd098e    1
# f66db67b37551e70f9f19e8f33aa866c    1
# f66db4a2b50361e12a1855ba02deb7fe    1
# f66db46cb8412ca1b3ecf6a16fc86542    1
# ffffff75ba4f33d938ccfdb148b8ea16    1
# Name: MachineIdentifier, Length: 500000, dtype: int64
# Columna ProductName tiene 4 valores únicos
# win8defender     494621
# mse                5375
# mseprerelease         3
# scep                  1
# Name: ProductName, dtype: int64
# Columna EngineVersion tiene 55 valores únicos
# 1.1.15200.1    215723
# 1.1.15100.1    206068
# 1.1.15000.2     14869
# 1.1.14901.4     11865
# 1.1.14600.4      9014
# 1.1.14800.3      7615
# 1.1.15300.6      6706
# 1.1.14104.0      5296
# 1.1.13504.0      3869
# 1.1.15300.5      3797
# 1.1.14700.5      2622
# 1.1.14500.5      2577
# 1.1.14405.2      2043
# 1.1.14306.0      1380
# 1.1.14202.0       851
# 1.1.14003.0       791
# 1.1.13903.0       527
# 1.1.13303.0       524
# 1.1.13804.0       506
# 1.1.13407.0       478
# 1.1.13601.0       407
# 1.1.14305.0       281
# 1.1.12902.0       278
# 1.1.13704.0       277
# 1.1.13701.0       266
# 1.1.13202.0       246
# 1.1.13103.0       238
# 1.1.13000.0       220
# 1.1.15000.1       161
# 1.1.12805.0       144
# 1.1.14901.3        91
# 1.1.14700.4        69
# 1.1.14700.3        66
# 1.1.14800.1        57
# 1.1.14500.2        15
# 1.1.14303.0        13
# 1.1.14201.0        11
# 1.1.13902.0         5
# 1.1.14103.0         5
# 1.1.12400.0         5
# 1.1.14001.0         4
# 1.1.11903.0         2
# 1.1.13802.0         2
# 1.1.12603.0         2
# 1.1.12205.0         2
# 1.1.12101.0         2
# 1.1.11701.0         2
# 1.1.14102.0         1
# 1.1.14002.0         1
# 1.1.13803.0         1
# 1.1.13406.0         1
# 1.1.12804.0         1
# 1.1.12706.0         1
# 1.1.12505.0         1
# 1.1.12300.0         1
# Name: EngineVersion, dtype: int64
# Columna AppVersion tiene 94 valores únicos
# 4.18.1807.18075    288047
# 4.18.1806.18062     47381
# 4.12.16299.15       20146
# 4.10.209.0          15324
# 4.13.17134.1        14409
#                     ...
# 4.13.17634.1000         1
# 4.13.17604.1000         1
# 4.4.306.0               1
# 4.15.17655.1000         1
# 4.15.17650.1001         1
# Name: AppVersion, Length: 94, dtype: int64
# Columna AvSigVersion tiene 6479 valores únicos
# 1.273.1420.0    5669
# 1.275.1140.0    5483
# 1.263.48.0      5419
# 1.275.727.0     5102
# 1.273.371.0     4953
#                 ...
# 1.235.450.0        1
# 1.235.470.0        1
# 1.235.473.0        1
# 1.235.476.0        1
# 1.249.1292.0       1
# Name: AvSigVersion, Length: 6479, dtype: int64
# Columna Platform tiene 4 valores únicos
# windows10      483012
# windows8        10887
# windows7         5314
# windows2016       787
# Name: Platform, dtype: int64
# Columna Processor tiene 3 valores únicos
# x64      453829
# x86       46152
# arm64        19
# Name: Processor, dtype: int64
# Columna OsVer tiene 13 valores únicos
# 10.0.0.0     483778
# 6.3.0.0       10885
# 6.1.1.0        5278
# 6.1.0.0          34
# 10.0.3.0          8
# 10.0.1.0          4
# 10.0.7.0          4
# 10.0.2.0          2
# 10.0.5.18         2
# 6.1.3.0           2
# 10.0.6.0          1
# 6.3.1.0           1
# 6.3.3.0           1
# Name: OsVer, dtype: int64
# Columna OsPlatformSubRelease tiene 9 valores únicos
# rs4           219325
# rs3           140079
# rs2            43845
# rs1            40924
# th2            23176
# th1            15245
# windows8.1     10887
# windows7        5314
# prers5          1205
# Name: OsPlatformSubRelease, dtype: int64
# Columna OsBuildLab tiene 467 valores únicos
# 17134.1.amd64fre.rs4_release.180410-1804                 204757
# 16299.431.amd64fre.rs3_release_svc_escrow.180502-1908     70304
# 16299.15.amd64fre.rs3_release.170928-1534                 53381
# 15063.0.amd64fre.rs2_release.170317-1834                  40223
# 17134.1.x86fre.rs4_release.180410-1804                    14554
#                                                           ...
# 17754.1000.amd64fre.rs5_release_sigma.180831-1700             1
# 17750.1000.amd64fre.rs5_release.180827-1459                   1
# 9600.18090.amd64fre.winblue_ltsb.151014-0600                  1
# 9600.18007.amd64fre.winblue_ltsb.150807-0612                  1
# 9600.19128.x86fre.winblue_ltsb_escrow.180813-1030             1
# Name: OsBuildLab, Length: 467, dtype: int64
# Columna SkuEdition tiene 8 valores únicos
# Home               308921
# Pro                180645
# Invalid              4444
# Education            2407
# Enterprise           1967
# Enterprise LTSB      1137
# Cloud                 303
# Server                176
# Name: SkuEdition, dtype: int64
# Columna PuaMode tiene 1 valores únicos
# on    136
# Name: PuaMode, dtype: int64
# Columna SmartScreen tiene 13 valores únicos
# RequireAdmin    242571
# ExistsNotSet     58709
# Off              10477
# Warn              7591
# Prompt            1905
# Block             1313
# off                 67
# On                  37
# &#x01;              20
# &#x02;              13
# on                  10
# &#x02                7
# &#x01                3
# Name: SmartScreen, dtype: int64
# Columna Census_MDC2FormFactor tiene 12 valores únicos
# Notebook        320871
# Desktop         109294
# Convertible      22609
# Detachable       16779
# AllInOne         16374
# PCOther           7857
# LargeTablet       3762
# SmallTablet       1737
# SmallServer        470
# MediumServer       173
# LargeServer         61
# ServerOther          3
# Name: Census_MDC2FormFactor, dtype: int64
# Columna Census_DeviceFamily tiene 3 valores únicos
# Windows.Desktop    499196
# Windows.Server        792
# Windows                 2
# Name: Census_DeviceFamily, dtype: int64
# Columna Census_ProcessorClass tiene 3 valores únicos
# mid     1157
# low      541
# high     347
# Name: Census_ProcessorClass, dtype: int64
# Columna Census_PrimaryDiskTypeName tiene 4 valores únicos
# HDD            325444
# SSD            137998
# UNKNOWN         20244
# Unspecified     15575
# Name: Census_PrimaryDiskTypeName, dtype: int64
# Columna Census_ChassisTypeName tiene 31 valores únicos
# Notebook               294297
# Desktop                104835
# Laptop                  38383
# Portable                20298
# AllinOne                11442
# MiniTower                4745
# Convertible              4679
# Other                    4228
# UNKNOWN                  3791
# Detachable               2891
# LowProfileDesktop        2768
# HandHeld                 2590
# SpaceSaving              1696
# Tablet                    729
# Tower                     715
# MainServerChassis         544
# Unknown                   540
# MiniPC                    246
# LunchBox                  210
# RackMountChassis          191
# BusExpansionChassis        44
# SubNotebook                40
# 30                         13
# 0                          10
# StickPC                     9
# MultisystemChassis          3
# SealedCasePC                3
# Blade                       2
# 35                          2
# 31                          2
# 44                          1
# Name: Census_ChassisTypeName, dtype: int64
# Columna Census_PowerPlatformRoleName tiene 9 valores únicos
# Mobile               346434
# Desktop              115678
# Slate                 27800
# Workstation            6089
# SOHOServer             2178
# UNKNOWN                1161
# EnterpriseServer        402
# AppliancePC             238
# PerformanceServer         8
# Name: Census_PowerPlatformRoleName, dtype: int64
# Columna Census_InternalBatteryType tiene 31 valores únicos
# lion    114224
# li-i     13953
# #        10304
# lip       3444
# liio      1746
# li p       470
# li         384
# nimh       256
# real       143
# bq20       126
# pbac       121
# vbox        84
# unkn        26
# lipo        23
# lgi0        21
# lhp0        10
# lipp         8
# 4cel         4
# ithi         4
# ram          3
# bad          3
# ÿÿÿÿ         2
# batt         2
# lÿÿÿ         1
# lai0         1
# pad0         1
# d            1
# asmb         1
# a132         1
# 4ion         1
# lio         1
# Name: Census_InternalBatteryType, dtype: int64
# Columna Census_OSVersion tiene 303 valores únicos
# 10.0.17134.228     79213
# 10.0.17134.165     50437
# 10.0.16299.431     30720
# 10.0.17134.285     26314
# 10.0.16299.547     19626
#                    ...
# 10.0.17643.1000        1
# 10.0.17711.1000        1
# 10.0.17713.1000        1
# 10.0.17723.1000        1
# 6.2.9200.21703         1
# Name: Census_OSVersion, Length: 303, dtype: int64
# Columna Census_OSArchitecture tiene 3 valores únicos
# amd64    453899
# x86       46072
# arm64        19
# Name: Census_OSArchitecture, dtype: int64
# Columna Census_OSBranch tiene 18 valores únicos
# rs4_release                  224583
# rs3_release                   69060
# rs3_release_svc_escrow        67248
# rs2_release                   44778
# rs1_release                   44003
# th2_release                   18424
# th2_release_sec               15000
# th1_st1                       11041
# th1                            4281
# rs5_release                     879
# rs3_release_svc_escrow_im       346
# rs_prerelease                   175
# rs_prerelease_flt               165
# rs5_release_sigma                 3
# rs_xbox                           1
# rs1_release_srvmedia              1
# win8_gdr                          1
# win8_ldr                          1
# Name: Census_OSBranch, dtype: int64
# Columna Census_OSEdition tiene 23 valores únicos
# Core                           194714
# Professional                   175500
# CoreSingleLanguage             108761
# CoreCountrySpecific              9267
# ProfessionalEducation            3107
# Education                        2382
# Enterprise                       2030
# ProfessionalN                    1570
# EnterpriseS                      1102
# ServerStandard                    582
# Cloud                             338
# CoreN                             264
# ServerStandardEval                133
# EducationN                         69
# EnterpriseSN                       48
# ServerDatacenterEval               43
# ServerSolution                     34
# EnterpriseN                        21
# ProfessionalEducationN             11
# ProfessionalWorkstation            11
# ProfessionalCountrySpecific         1
# CloudN                              1
# professional                        1
# Name: Census_OSEdition, dtype: int64
# Columna Census_OSSkuName tiene 21 valores únicos
# CORE                            194716
# PROFESSIONAL                    178634
# CORE_SINGLELANGUAGE             108731
# CORE_COUNTRYSPECIFIC              9254
# EDUCATION                         2388
# ENTERPRISE                        2042
# PROFESSIONAL_N                    1580
# ENTERPRISE_S                      1102
# STANDARD_SERVER                    582
# CLOUD                              336
# CORE_N                             264
# STANDARD_EVALUATION_SERVER         133
# EDUCATION_N                         67
# ENTERPRISE_S_N                      48
# DATACENTER_EVALUATION_SERVER        43
# SB_SOLUTION_SERVER                  34
# ENTERPRISE_N                        22
# PRO_WORKSTATION                     11
# PRO_CHINA                            1
# CLOUDN                               1
# UNLICENSED                           1
# Name: Census_OSSkuName, dtype: int64
# Columna Census_OSInstallTypeName tiene 9 valores únicos
# UUPUpgrade        146610
# IBSClean           91915
# Update             89264
# Upgrade            70380
# Other              47100
# Reset              36435
# Refresh            11538
# Clean               3737
# CleanPCRefresh      3011
# Name: Census_OSInstallTypeName, dtype: int64
# Columna Census_OSWUAutoUpdateOptionsName tiene 6 valores únicos
# FullAuto                                 221461
# UNKNOWN                                  140707
# Notify                                   114590
# AutoInstallAndRebootAtMaintenanceTime     20954
# Off                                        1491
# DownloadNotify                              787
# Name: Census_OSWUAutoUpdateOptionsName, dtype: int64
# Columna Census_GenuineStateName tiene 4 valores únicos
# IS_GENUINE         441929
# INVALID_LICENSE     44513
# OFFLINE             12772
# UNKNOWN               776
# Name: Census_GenuineStateName, dtype: int64
# Columna Census_ActivationChannel tiene 6 valores únicos
# Retail            264644
# OEM:DM            191212
# Volume:GVLK        25482
# OEM:NONSLP         18042
# Volume:MAK           434
# Retail:TB:Eval       176
# Name: Census_ActivationChannel, dtype: int64
# Columna Census_FlightRing tiene 9 valores únicos
# Retail      468236
# NOT_SET      16206
# Unknown      13590
# WIF            612
# WIS            581
# RP             553
# Disabled       210
# Canary           1
# OSG              1
# Name: Census_FlightRing, dtype: int64

# %% [markdown]
# ###Valores faltantes

# %%
k = d.isna().sum()
k1 = k[k!=0]
fig, ax = plt.subplots()
ax.plot(k1)
plt.xticks(rotation=90)
plt.xticks(fontsize=5)
plt.plot(k1)

# %% [markdown]
# ###Distribución de la variable objetivo

# %%
sns.distplot(d['HasDetections']);
plt.xticks([0, 1],["No", "Yes"])
# Out:
# <ipython-input-10-4bb9669e2e1d>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(d['HasDetections']);
# ([<matplotlib.axis.XTick at 0x7f9cd90797e0>,
#   <matplotlib.axis.XTick at 0x7f9cd90797b0>],
#  [Text(0, 0, 'No'), Text(1, 0, 'Yes')])

# %% [markdown]
# ### Distribución de otras variables

# %%
c="Processor"
d[c].value_counts()
# Out:
# x64      453829
# x86       46152
# arm64        19
# Name: Processor, dtype: int64

# %%
plt.figure(figsize=(20,8))
for i,c in enumerate(["Census_ProcessorClass", "Platform", "Processor", "Census_GenuineStateName"]):    
    plt.subplot(2,4,i+1)
    k=d[[c,"HasDetections"]].dropna()
    for v in k[c].unique():
        sns.distplot(k.loc[k[c] == v, "HasDetections"], label=v)
        plt.title(c)
    plt.yticks([])
    plt.legend()

    plt.subplot(2, 4, i+5)
    vc = k[c].value_counts()
    sns.barplot(x=vc.index, y=vc.values)
    plt.xticks(rotation=90)
# Out:
# <ipython-input-12-2dcdec65621e>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(k.loc[k[c] == v, "HasDetections"], label=v)
# <ipython-input-12-2dcdec65621e>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(k.loc[k[c] == v, "HasDetections"], label=v)
# <ipython-input-12-2dcdec65621e>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(k.loc[k[c] == v, "HasDetections"], label=v)
# <ipython-input-12-2dcdec65621e>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(k.loc[k[c] == v, "HasDetections"], label=v)
# <ipython-input-12-2dcdec65621e>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(k.loc[k[c] == v, "HasDetections"], label=v)
# <ipython-input-12-2dcdec65621e>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(k.loc[k[c] == v, "HasDetections"], label=v)
# <ipython-input-12-2dcdec65621e>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(k.loc[k[c] == v, "HasDetections"], label=v)
# <ipython-input-12-2dcdec65621e>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(k.loc[k[c] == v, "HasDetections"], label=v)
# <ipython-input-12-2dcdec65621e>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(k.loc[k[c] == v, "HasDetections"], label=v)
# <ipython-input-12-2dcdec65621e>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(k.loc[k[c] == v, "HasDetections"], label=v)
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py:2511: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# <ipython-input-12-2dcdec65621e>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(k.loc[k[c] == v, "HasDetections"], label=v)
# <ipython-input-12-2dcdec65621e>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(k.loc[k[c] == v, "HasDetections"], label=v)
# <ipython-input-12-2dcdec65621e>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(k.loc[k[c] == v, "HasDetections"], label=v)
# <ipython-input-12-2dcdec65621e>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(k.loc[k[c] == v, "HasDetections"], label=v)

# %% [markdown]
# ### Correlación entre variables

# %% [markdown]
# Correlación entre algunas variables

# %%
cols = ['IsBeta', 'DefaultBrowsersIdentifier', 'Firewall', 'Census_IsFlightingInternal', 'Census_ThresholdOptIn', 'Census_IsWIMBootEnabled', 'HasDetections']
sns.set()
sns.pairplot(d[cols])

# %% [markdown]
# Correlación entre todas las variables

# %%
corrmat = d.corr()
f, ax = plt.subplots(figsize=(12, 9))
plt.xticks(fontsize=5)
plt.yticks(fontsize=5)
sns.heatmap(corrmat, vmax=.8, square=True);
# Out:
# <ipython-input-14-e8f5c3655a44>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrmat = d.corr()
